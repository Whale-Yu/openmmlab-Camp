# %% [markdown]
# # 预测网图

# %%
import os
os.chdir('mmdetection')

# %%
# !wget http://digitalpaper.stdaily.com/http_www.kjrb.com/kjrb/images/2020-10/22/04/824719_lix_1603271812153_b.jpg -O balloon_dataset/balloon_test.png
# Out:
# --2023-06-09 08:49:08--  http://digitalpaper.stdaily.com/http_www.kjrb.com/kjrb/images/2020-10/22/04/824719_lix_1603271812153_b.jpg
# Resolving digitalpaper.stdaily.com (digitalpaper.stdaily.com)... 58.220.69.111, 58.220.73.254
# Connecting to digitalpaper.stdaily.com (digitalpaper.stdaily.com)|58.220.69.111|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64987 (63K) [image/jpeg]
# Saving to: ‘balloon_dataset/balloon_test.png’
#
# balloon_dataset/bal 100%[===================>]  63.46K  --.-KB/s    in 0.06s
#
# 2023-06-09 08:49:09 (1.02 MB/s) - ‘balloon_dataset/balloon_test.png’ saved [64987/64987]

# %%
# !/root/miniconda3/envs/myconda/bin/python demo/image_demo.py balloon_dataset/balloon_test.png balloon_dataset/balloon_rtmdet.py --weights work_dirs/balloon_rtmdet/best_coco_bbox_mAP_epoch_120.pth
# Out:
# Loads checkpoint by local backend from path: work_dirs/balloon_rtmdet/best_coco_bbox_mAP_epoch_120.pth
# 06/09 09:04:01 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/09 09:04:01 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/torch/functional.py:47━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 8: UserWarning: torch.meshgrid: in an upcoming release, it will be required to
# pass the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# results have been saved at outputs

# %%
from PIL import Image
Image.open('outputs/vis/balloon_test.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x266>
