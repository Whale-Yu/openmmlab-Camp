# %% [markdown]
# # 预测单张图片

# %%
import os
os.chdir('mmdetection')

# %%
# !/root/miniconda3/envs/myconda/bin/python demo/image_demo.py \
    mask_dataset/mask22.jpg \
    mask_dataset/mask_rtmdet.py \
    --weights work_dirs/mask_rtmdet/best_coco_bbox_mAP_epoch_70.pth
# Out:
# Loads checkpoint by local backend from path: work_dirs/mask_rtmdet/best_coco_bbox_mAP_epoch_70.pth
# 06/12 02:53:03 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/12 02:53:03 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/torch/functional.py:47━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 8: UserWarning: torch.meshgrid: in an upcoming release, it will be required to
# pass the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
from PIL import Image
Image.open('outputs/vis/mask22.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x281>
