# %%
import os
os.chdir('mmpretrain')

# %%
# !wget https://scpic2.chinaz.net/files/default/imgs/2023-05-14/f42b56e9c121cc82_s.jpg -O cat.jpg
# !wget https://scpic3.chinaz.net/Files/pic/pic9/201609/fpic7037_s.jpg -O dog.jpg
# Out:
# --2023-06-06 12:31:45--  https://scpic2.chinaz.net/files/default/imgs/2023-05-14/f42b56e9c121cc82_s.jpg
# Resolving scpic2.chinaz.net (scpic2.chinaz.net)... 150.138.105.234
# Connecting to scpic2.chinaz.net (scpic2.chinaz.net)|150.138.105.234|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42955 (42K) [image/jpeg]
# Saving to: ‘cat.jpg’
#
# cat.jpg             100%[===================>]  41.95K  --.-KB/s    in 0.004s
#
# 2023-06-06 12:31:45 (10.9 MB/s) - ‘cat.jpg’ saved [42955/42955]
#
# --2023-06-06 12:31:46--  https://scpic3.chinaz.net/Files/pic/pic9/201609/fpic7037_s.jpg
# Resolving scpic3.chinaz.net (scpic3.chinaz.net)... 150.138.105.234
# Connecting to scpic3.chinaz.net (scpic3.chinaz.net)|150.138.105.234|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10626 (10K) [image/jpeg]
# Saving to: ‘dog.jpg’
#
# dog.jpg             100%[===================>]  10.38K  --.-KB/s    in 0.001s
#
# ...

# %%
from mmpretrain import ImageClassificationInferencer

inf=ImageClassificationInferencer('myconfig/resnet18_finetune.py',pretrained='work_dirs/epoch_5.pth')

inf('dog.jpg',show=True)
# Out:
# Loads checkpoint by local backend from path: work_dirs/epoch_5.pth
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 06/06 12:31:52 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [{'pred_scores': array([0.41295058, 0.5870495 ], dtype=float32),
#   'pred_label': 1,
#   'pred_score': 0.5870494842529297,
#   'pred_class': 'dogs'}]

# %% [markdown]
# # demo.py预测

# %%
# !/root/miniconda3/envs/myconda/bin/python \
    demo/image_demo.py \
    demo/dog.jpg \
    myconfig/resnet18_finetune.py \
    --checkpoint work_dirs/epoch_5.pth \
    --show-dir outputs/
# Out:
# Loads checkpoint by local backend from path: work_dirs/epoch_5.pth
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# 06/06 12:38:20 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# {
#   "pred_label": 0,
#   "pred_score": 0.6262472867965698,
#   "pred_class": "cats"
# }

# %%
# 查看预测出来的图片
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('outputs/dog.png')

plt.imshow(img)

plt.show()
